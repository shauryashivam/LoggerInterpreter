# %%
import os
import time 
from time import sleep
import datetime
from datetime import datetime
import serial
from serial import *

ser = serial.Serial(port='COM3',baudrate = 115200)
counter=0

file = open("new_log.csv","a")
i=0

if os.stat("new_log.csv").st_size == 0:
     file.write("Time,Sensor1,Sensor2,Sensor3,Sensor4,Sensor5\n")
while True:
    with open("data_log1.csv", "a") :

            i=str(ser.read(20))
            j=i.split(',')
            now = datetime.now()
            print("Logging in:",i)
            print(str(now),j)
            file.write(str(now)+","+i+"\n")
            file.flush()
            time.sleep(5)
file.close()
# Out:
# ('Logging in:', '43,59,49,60,94 37,26')
# ('2019-05-31 14:58:05.836000', ['43', '59', '49', '60', '94 37', '26'])
# ('Logging in:', ',55,10,21 62,61,86,8')
# ('2019-05-31 14:58:10.838000', ['', '55', '10', '21 62', '61', '86', '8'])
# ('Logging in:', '0,69 38,44,40,32,42 ')
# ('2019-05-31 14:58:15.840000', ['0', '69 38', '44', '40', '32', '42 '])
# ('Logging in:', '74,73,37,10,49 45,88')
# ('2019-05-31 14:58:20.842000', ['74', '73', '37', '10', '49 45', '88'])
# ('Logging in:', ',72,78,85 13,92,54,2')
# ('2019-05-31 14:58:25.846000', ['', '72', '78', '85 13', '92', '54', '2'])
# ('Logging in:', '3,85 77,24,43,26,97 ')
# ('2019-05-31 14:58:30.850000', ['3', '85 77', '24', '43', '26', '97 '])
# ('Logging in:', '28,51,57,83,22 18,22')
# ('2019-05-31 14:58:35.853000', ['28', '51', '57', '83', '22 18', '22'])
# ('Logging in:', ',96,74,54 63,79,58,9')
# ('2019-05-31 14:58:40.854000', ['', '96', '74', '54 63', '79', '58', '9'])
# ('Logging in:', '7,24 23,90,69,70,72 ')
# ...

# %%
pwd
# Out:
# u'C:\\Users\\sscbs'

# %%
# !pip
